# %%
import numpy as np

# %%
from qiskit import *

# %%
# On crée un circuit quantique

# %%
circ = QuantumCircuit(8)

# %%
# Affichons le cicruit

# %%
circ.draw()
# Out:
#
# q_0:
#
# q_1:
#
# q_2:
#
# q_3:
#
# q_4:
#
# q_5:
#
# q_6:
#
# q_7:

# %%
circ.draw('mpl')

# %%
circ.h(0)
circ.h(1)
circ.h(2)
circ.h(3)

# %%
# h = porte de Hadamard = superposition d'un qubit

# %%
circ.draw('mpl')

# %%
#On utilse des portes cnot pour trouver la parité des cheveux indigo du point de vue de ALice
circ.cx(1,4)
circ.cx(2,4)
circ.cx(3,4)

# %%
circ.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├────────────────────────────────────────────────────────────
#      ├───┤
# q_1: ┤ H ├──■─────────────────────────────────────────────────────────
#      ├───┤  │
# q_2: ┤ H ├──┼────■───────────────────■────────────────────────────────
#      ├───┤  │    │                   │
# q_3: ┤ H ├──┼────┼────■──────────────┼─────────■──────────────■───────
#      └───┘┌─┴─┐┌─┴─┐┌─┴─┐            │         │              │
# q_4: ─────┤ X ├┤ X ├┤ X ├──■────■────┼────■────┼──────────────┼───────
#           └───┘└───┘└───┘┌─┴─┐  │  ┌─┴─┐  │  ┌─┴─┐            │
# q_5: ────────────────────┤ X ├──┼──┤ X ├──┼──┤ X ├──■────■────┼───────
#                          └───┘┌─┴─┐└───┘  │  └───┘┌─┴─┐  │  ┌─┴─┐
# q_6: ─────────────────────────┤ X ├───────┼───────┤ X ├──┼──┤ X ├──■──
#                               └───┘     ┌─┴─┐     └───┘┌─┴─┐└───┘┌─┴─┐
# q_7: ───────────────────────────────────┤ X ├──────────┤ X ├─────┤ X ├
# ...

# %%
circ.draw('mpl')

# %%
#Chaque personne prends note de la parité
circ.cx(4,5)
circ.cx(4,6)
circ.cx(4,7)

circ.draw('mpl')

# %%
#On utilse des portes cnot pour trouver la parité des cheveux indigo du point de vue de Bob
circ.cx(2,5)
circ.cx(3,5)

#Les deux personnes restante prend note de la parité
circ.cx(5,6)
circ.cx(5,7)

circ.draw('mpl')

# %%
#On utilse des portes cnot pour trouver la parité des cheveux indigo du point de vue de Charlie
circ.cx(3,6)

#Dahlia prend note de la parité
circ.cx(6,7)

circ.draw('mpl')
